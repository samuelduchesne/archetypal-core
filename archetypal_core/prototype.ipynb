# %%
from archetypal_core.models.models import IDF

# %%
with open("/Applications/EnergyPlus-23-1-0/ExampleFiles/RefBldgMediumOfficeNew2004_Chicago_epJSON.epJSON") as f:
    idf = IDF.model_validate_json(f.read())
idf
# Out:
# IDF(Version={'Version 1': Version(version_identifier='23.1')}, SimulationControl={'SimulationControl 1': SimulationControl(do_zone_sizing_calculation='Yes', do_system_sizing_calculation='Yes', do_plant_sizing_calculation='Yes', run_simulation_for_sizing_periods='Yes', run_simulation_for_weather_file_run_periods='No', do_hvac_sizing_simulation_for_sizing_periods='No', maximum_number_of_hvac_sizing_simulation_passes=1)}, PerformancePrecisionTradeoffs=None, Building={'Ref Bldg Medium Office New2004_v1.3_5.0': Building(north_axis=0.0, terrain='City', loads_convergence_tolerance_value=0.04, temperature_convergence_tolerance_value=0.2, solar_distribution='FullInteriorAndExterior', maximum_number_of_warmup_days=25, minimum_number_of_warmup_days=6)}, ShadowCalculation={'ShadowCalculation 1': ShadowCalculation(shading_calculation_method='PolygonClipping', shading_calculation_update_frequency_method='Periodic', shading_calculation_update_frequency=7, maximum_figures_in_shadow_overlap_calculations=15000, polygon_clipping_algorithm='SutherlandHodgman', pixel_counting_resolution=512, sky_diffuse_modeling_algorithm='SimpleSkyDiffuseModeling', output_external_shading_calculation_results='No', disable_self_shading_within_shading_zone_groups='No', disable_self_shading_from_shading_zone_groups_to_other_zones='No', shading_zone_groups=None)}, SurfaceConvectionAlgorithm:Inside={'SurfaceConvectionAlgorithm:Inside 1': SurfaceConvectionAlgorithm_Inside(algorithm='TARP')}, SurfaceConvectionAlgorithm:Outside={'SurfaceConvectionAlgorithm:Outside 1': SurfaceConvectionAlgorithm_Outside(algorithm='DOE-2')}, HeatBalanceAlgorithm={'HeatBalanceAlgorithm 1': HeatBalanceAlgorithm(algorithm='ConductionTransferFunction', surface_temperature_upper_limit=200.0, minimum_surface_convection_heat_transfer_coefficient_value=0.1, maximum_surface_convection_heat_transfer_coefficient_value=1000.0)}, HeatBalanceSettings:ConductionFiniteDifference=None, ZoneAirHeatBalanceAlgorithm={'ZoneAirHeatBalanceAlgorithm 1': ZoneAirHeatBalanceAlgorithm(algorithm='AnalyticalSolution', do_space_heat_balance_for_sizing='No', do_space_heat_balance_for_simulation='No')}, ZoneAirContaminantBalance=None, ZoneAirMassFlowConservation=None, ZoneCapacitanceMultiplier:ResearchSpecial=None, Timestep={'Timestep 1': Timestep(number_of_timesteps_per_hour=6)}, ConvergenceLimits={'ConvergenceLimits 1': ConvergenceLimits(minimum_system_timestep=2, maximum_hvac_iterations=25, minimum_plant_iterations=2, maximum_plant_iterations=8)}, HVACSystemRootFindingAlgorithm=None, Compliance:Building=None, Site:Location={'USA IL-CHICAGO-OHARE': Site_Location(latitude=41.77, longitude=-87.75, time_zone=-6.0, elevation=190.0)}, Site:VariableLocation=None, SizingPeriod:DesignDay={'CHICAGO Ann Clg .4% Condns WB=>MDB': SizingPeriod_DesignDay(month=7, day_of_month=21, day_type='SummerDesignDay', maximum_dry_bulb_temperature=31.2, daily_dry_bulb_temperature_range=10.7, dry_bulb_temperature_range_modifier_type='DefaultMultipliers', dry_bulb_temperature_range_modifier_day_schedule_name=None, humidity_condition_type='WetBulb', wetbulb_or_dewpoint_at_maximum_dry_bulb=25.5, humidity_condition_day_schedule_name=None, humidity_ratio_at_maximum_dry_bulb=None, enthalpy_at_maximum_dry_bulb=None, daily_wet_bulb_temperature_range=None, barometric_pressure=99063.0, wind_speed=5.3, wind_direction=230.0, rain_indicator='No', snow_indicator='No', daylight_saving_time_indicator='No', solar_model_indicator='ASHRAEClearSky', beam_solar_day_schedule_name=None, diffuse_solar_day_schedule_name=None, ashrae_clear_sky_optical_depth_for_beam_irradiance_taub_=0.0, ashrae_clear_sky_optical_depth_for_diffuse_irradiance_taud_=0.0, sky_clearness=1.0, maximum_number_warmup_days=None, begin_environment_reset_mode='FullResetAtBeginEnvironment'), 'CHICAGO Ann Htg 99.6% Condns DB': SizingPeriod_DesignDay(month=1, day_of_month=21, day_type='WinterDesignDay', maximum_dry_bulb_temperature=-20.6, daily_dry_bulb_temperature_range=0.0, dry_bulb_temperature_range_ ...

# %%
import json

with open("schema.json", "w") as f:
    json.dump(IDF.model_json_schema(), f, indent=True)
